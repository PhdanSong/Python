# %%
import random
import numpy as np
import csv

class TableNode(object):
    def __init__(self, index):
        self.val = index
        self.buckets = {}


def genPara(n, r):
    """
    :param n: length of data vector
    :param r:
    :return: a, b
    """

    a = []
    for i in range(n):
        a.append(random.gauss(0, 1))
    b = random.uniform(0, r)

    return a, b


def gen_e2LSH_family(n, k, r):
    """
    :param n: length of data vector
    :param k: the number of hash function
    :param r: the width of bucket
    :return: a list of parameters (a, b)
    """
    result = []
    for i in range(k):
        result.append(genPara(n, r))

    return result


def gen_HashVals(e2LSH_family, v, r):
    """
    :param e2LSH_family: include k hash funcs(parameters)
    :param v: data vector
    :param r:the width of bucket
    :return hash values: a list
    """

    # hashVals include k values
    hashVals = []

    for hab in e2LSH_family:
        hashVal = (np.inner(hab[0], v) + hab[1]) // r
        hashVals.append(hashVal)

    return hashVals


def H2(hashVals, fpRand, k, C):
    """
    :param hashVals: k hash vals
    :param fpRand: ri', the random vals that used to generate fingerprint
    :param k, C: parameter
    :return: the fingerprint of (x1, x2, ..., xk), a int value
    """
    return int(sum([(hashVals[i] * fpRand[i]) for i in range(k)]) % C)


def e2LSH(dataSet, k, L, r, tableSize):
    """
    generate hash table
    * hash table: a list, [node1, node2, ... node_{tableSize - 1}]
    ** node: node.val = index; node.buckets = {}
    *** node.buckets: a dictionary, {fp:[v1, ..], ...}
    :param dataSet: a set of vector(list)
    :param k:the number of hash function
    :param L:
    :param r:
    :param tableSize:
    :return: 3 elements, hash table, hash functions, fpRand
    """

    hashTable = [TableNode(i) for i in range(tableSize)]

    #数据集列数
    n = len(dataSet[0])
    #数据集行数
    m = len(dataSet)

    C = pow(2, 32) - 5
    hashFuncs = []
    fpRand = [random.randint(-10, 10) for i in range(k)]

    for times in range(L):

        #得到k个hash 函数
        e2LSH_family = gen_e2LSH_family(n, k, r)

        # hashFuncs: [[h1, ...hk], [h1, ..hk], ..., [h1, ...hk]]
        # hashFuncs include L hash functions group, and each group contain k hash functions
        hashFuncs.append(e2LSH_family)

        #对于数据集的每一行
        for dataIndex in range(m):

            print("start****************************************************")
            print("dataIndex")
            print(dataIndex)
            # generate k hash values 得到k个hash值
            hashVals = gen_HashVals(e2LSH_family, dataSet[dataIndex], r)

            print("hashVals")
            print(hashVals)
            # generate fingerprint
            fp = H2(hashVals, fpRand, k, C)
            print("fp")
            print(fp)
            # generate index
            index = fp % tableSize
            print("index")
            print(index)
            # find the node of hash table
            node = hashTable[index]
            print("node.val")
            print(node.val)
            print("node.buckets")
            print(node.buckets)
            # node.buckets is a dictionary: {fp: vector_list}
            if fp in node.buckets:

                # bucket is vector list
                bucket = node.buckets[fp]

                # add the data index into bucket
                bucket.append(dataIndex)

            else:
                node.buckets[fp] = [dataIndex]
            print("node.buckets[fp]")
            print(node.buckets[fp])
                
        print("end-------------------------------------------------")
    return hashTable, hashFuncs, fpRand


def nn_search(dataSet, query, k, L, r, tableSize):
    """
    :param dataSet:
    :param query:
    :param k:
    :param L:
    :param r:
    :param tableSize:
    :return: the data index that similar with query
    """

    result = set()

    temp = e2LSH(dataSet, k, L, r, tableSize)
    C = pow(2, 32) - 5

    hashTable = temp[0]
    hashFuncGroups = temp[1]
    fpRand = temp[2]

    for hashFuncGroup in hashFuncGroups:

        # get the fingerprint of query
        queryFp = H2(gen_HashVals(hashFuncGroup, query, r), fpRand, k, C)

        # get the index of query in hash table
        queryIndex = queryFp % tableSize

        # get the bucket in the dictionary
        if queryFp in hashTable[queryIndex].buckets:
            result.update(hashTable[queryIndex].buckets[queryFp])

    return result


def readData(fileName):
    """read csv data"""

    dataSet = []
    with open(fileName, "r") as csvFile:
        reader = csv.reader(csvFile)
        for line in reader:
            dataSet.append([float(item) for item in line])

    return dataSet


def euclideanDistance(v1, v2):
    """get euclidean distance of 2 vectors"""

    v1, v2 = np.array(v1), np.array(v2)
    return np.sqrt(np.sum(np.square(v1 - v2)))

if __name__ == "__main__":

    dataSet = readData("./data/irisData.txt")
    
    hashTable,hashFuncs,fpRand= e2LSH(dataSet, k=3, L=4, r=1, tableSize=10)
     
    print("主程序")
    for i in range (10):
        node = hashTable[i]
        print("node.val")
        print(node.val)
        print("node.buckets")
        print(node.buckets)
         
         
    
#     query = [-2.7769, -5.6967, 5.9179, 0.37671, 1]
#     indexes = e2LSH.nn_search(dataSet, query, k=20, L=5, r=1, tableSize=20)
#     for index in indexes:
#         print(euclideanDistance(dataSet[index], query))
# Out:
# start****************************************************
# dataIndex
# 0
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {}
# node.buckets[fp]
# [0]
# start****************************************************
# dataIndex
# 1
# hashVals
# [3.0, -7.0, -4.0]
# fp
# 4294967167
# index
# 7
# node.val
# 7
# node.buckets
# {}
# node.buckets[fp]
# [1]
# start****************************************************
# dataIndex
# 2
# hashVals
# [3.0, -7.0, -4.0]
# fp
# 4294967167
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1]}
# node.buckets[fp]
# [1, 2]
# start****************************************************
# dataIndex
# 3
# hashVals
# [4.0, -7.0, -4.0]
# fp
# 4294967160
# index
# 0
# node.val
# 0
# node.buckets
# {}
# node.buckets[fp]
# [3]
# start****************************************************
# dataIndex
# 4
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0]}
# node.buckets[fp]
# [0, 4]
# start****************************************************
# dataIndex
# 5
# hashVals
# [4.0, -9.0, -4.0]
# fp
# 4294967142
# index
# 2
# node.val
# 2
# node.buckets
# {}
# node.buckets[fp]
# [5]
# start****************************************************
# dataIndex
# 6
# hashVals
# [4.0, -7.0, -4.0]
# fp
# 4294967160
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3]}
# node.buckets[fp]
# [3, 6]
# start****************************************************
# dataIndex
# 7
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4]}
# node.buckets[fp]
# [0, 4, 7]
# start****************************************************
# dataIndex
# 8
# hashVals
# [3.0, -7.0, -4.0]
# fp
# 4294967167
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2]}
# node.buckets[fp]
# [1, 2, 8]
# start****************************************************
# dataIndex
# 9
# hashVals
# [3.0, -7.0, -4.0]
# fp
# 4294967167
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8]}
# node.buckets[fp]
# [1, 2, 8, 9]
# start****************************************************
# dataIndex
# 10
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7]}
# node.buckets[fp]
# [0, 4, 7, 10]
# start****************************************************
# dataIndex
# 11
# hashVals
# [4.0, -7.0, -4.0]
# fp
# 4294967160
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6]}
# node.buckets[fp]
# [3, 6, 11]
# start****************************************************
# dataIndex
# 12
# hashVals
# [3.0, -7.0, -4.0]
# fp
# 4294967167
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9]}
# node.buckets[fp]
# [1, 2, 8, 9, 12]
# start****************************************************
# dataIndex
# 13
# hashVals
# [3.0, -6.0, -3.0]
# fp
# 4294967186
# index
# 6
# node.val
# 6
# node.buckets
# {}
# node.buckets[fp]
# [13]
# start****************************************************
# dataIndex
# 14
# hashVals
# [4.0, -9.0, -3.0]
# fp
# 4294967152
# index
# 2
# node.val
# 2
# node.buckets
# {4294967142: [5]}
# node.buckets[fp]
# [14]
# start****************************************************
# dataIndex
# 15
# hashVals
# [4.0, -9.0, -4.0]
# fp
# 4294967142
# index
# 2
# node.val
# 2
# node.buckets
# {4294967142: [5], 4294967152: [14]}
# node.buckets[fp]
# [5, 15]
# start****************************************************
# dataIndex
# 16
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10]}
# node.buckets[fp]
# [0, 4, 7, 10, 16]
# start****************************************************
# dataIndex
# 17
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17]
# start****************************************************
# dataIndex
# 18
# hashVals
# [4.0, -9.0, -4.0]
# fp
# 4294967142
# index
# 2
# node.val
# 2
# node.buckets
# {4294967142: [5, 15], 4294967152: [14]}
# node.buckets[fp]
# [5, 15, 18]
# start****************************************************
# dataIndex
# 19
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19]
# start****************************************************
# dataIndex
# 20
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20]
# start****************************************************
# dataIndex
# 21
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21]
# start****************************************************
# dataIndex
# 22
# hashVals
# [4.0, -7.0, -3.0]
# fp
# 4294967170
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11]}
# node.buckets[fp]
# [22]
# start****************************************************
# dataIndex
# 23
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23]
# start****************************************************
# dataIndex
# 24
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24]
# start****************************************************
# dataIndex
# 25
# hashVals
# [3.0, -8.0, -4.0]
# fp
# 4294967158
# index
# 8
# node.val
# 8
# node.buckets
# {}
# node.buckets[fp]
# [25]
# start****************************************************
# dataIndex
# 26
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26]
# start****************************************************
# dataIndex
# 27
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27]
# start****************************************************
# dataIndex
# 28
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28]
# start****************************************************
# dataIndex
# 29
# hashVals
# [4.0, -7.0, -4.0]
# fp
# 4294967160
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11], 4294967170: [22]}
# node.buckets[fp]
# [3, 6, 11, 29]
# start****************************************************
# dataIndex
# 30
# hashVals
# [4.0, -7.0, -4.0]
# fp
# 4294967160
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29], 4294967170: [22]}
# node.buckets[fp]
# [3, 6, 11, 29, 30]
# start****************************************************
# dataIndex
# 31
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31]
# start****************************************************
# dataIndex
# 32
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32]
# start****************************************************
# dataIndex
# 33
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33]
# start****************************************************
# dataIndex
# 34
# hashVals
# [3.0, -7.0, -4.0]
# fp
# 4294967167
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12]}
# node.buckets[fp]
# [1, 2, 8, 9, 12, 34]
# start****************************************************
# dataIndex
# 35
# hashVals
# [3.0, -7.0, -3.0]
# fp
# 4294967177
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34]}
# node.buckets[fp]
# [35]
# start****************************************************
# dataIndex
# 36
# hashVals
# [4.0, -8.0, -3.0]
# fp
# 4294967161
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33]}
# node.buckets[fp]
# [36]
# start****************************************************
# dataIndex
# 37
# hashVals
# [3.0, -7.0, -4.0]
# fp
# 4294967167
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34], 4294967177: [35]}
# node.buckets[fp]
# [1, 2, 8, 9, 12, 34, 37]
# start****************************************************
# dataIndex
# 38
# hashVals
# [3.0, -7.0, -4.0]
# fp
# 4294967167
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37], 4294967177: [35]}
# node.buckets[fp]
# [1, 2, 8, 9, 12, 34, 37, 38]
# start****************************************************
# dataIndex
# 39
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33], 4294967161: [36]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39]
# start****************************************************
# dataIndex
# 40
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39], 4294967161: [36]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40]
# start****************************************************
# dataIndex
# 41
# hashVals
# [3.0, -7.0, -4.0]
# fp
# 4294967167
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38], 4294967177: [35]}
# node.buckets[fp]
# [1, 2, 8, 9, 12, 34, 37, 38, 41]
# start****************************************************
# dataIndex
# 42
# hashVals
# [4.0, -7.0, -4.0]
# fp
# 4294967160
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30], 4294967170: [22]}
# node.buckets[fp]
# [3, 6, 11, 29, 30, 42]
# start****************************************************
# dataIndex
# 43
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40], 4294967161: [36]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43]
# start****************************************************
# dataIndex
# 44
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43], 4294967161: [36]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44]
# start****************************************************
# dataIndex
# 45
# hashVals
# [3.0, -7.0, -4.0]
# fp
# 4294967167
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41], 4294967177: [35]}
# node.buckets[fp]
# [1, 2, 8, 9, 12, 34, 37, 38, 41, 45]
# start****************************************************
# dataIndex
# 46
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44], 4294967161: [36]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46]
# start****************************************************
# dataIndex
# 47
# hashVals
# [4.0, -7.0, -4.0]
# fp
# 4294967160
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42], 4294967170: [22]}
# node.buckets[fp]
# [3, 6, 11, 29, 30, 42, 47]
# start****************************************************
# dataIndex
# 48
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46], 4294967161: [36]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48]
# start****************************************************
# dataIndex
# 49
# hashVals
# [4.0, -8.0, -4.0]
# fp
# 4294967151
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48], 4294967161: [36]}
# node.buckets[fp]
# [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49]
# start****************************************************
# dataIndex
# 50
# hashVals
# [6.0, -13.0, -9.0]
# fp
# 4294967042
# index
# 2
# node.val
# 2
# node.buckets
# {4294967142: [5, 15, 18], 4294967152: [14]}
# node.buckets[fp]
# [50]
# start****************************************************
# dataIndex
# 51
# hashVals
# [6.0, -12.0, -9.0]
# fp
# 4294967051
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36]}
# node.buckets[fp]
# [51]
# start****************************************************
# dataIndex
# 52
# hashVals
# [6.0, -13.0, -9.0]
# fp
# 4294967042
# index
# 2
# node.val
# 2
# node.buckets
# {4294967142: [5, 15, 18], 4294967152: [14], 4294967042: [50]}
# node.buckets[fp]
# [50, 52]
# start****************************************************
# dataIndex
# 53
# hashVals
# [5.0, -10.0, -9.0]
# fp
# 4294967076
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13]}
# node.buckets[fp]
# [53]
# start****************************************************
# dataIndex
# 54
# hashVals
# [5.0, -12.0, -9.0]
# fp
# 4294967058
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25]}
# node.buckets[fp]
# [54]
# start****************************************************
# dataIndex
# 55
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35]}
# node.buckets[fp]
# [55]
# start****************************************************
# dataIndex
# 56
# hashVals
# [6.0, -12.0, -9.0]
# fp
# 4294967051
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36], 4294967051: [51]}
# node.buckets[fp]
# [51, 56]
# start****************************************************
# dataIndex
# 57
# hashVals
# [5.0, -9.0, -8.0]
# fp
# 4294967095
# index
# 5
# node.val
# 5
# node.buckets
# {}
# node.buckets[fp]
# [57]
# start****************************************************
# dataIndex
# 58
# hashVals
# [5.0, -12.0, -9.0]
# fp
# 4294967058
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54]}
# node.buckets[fp]
# [54, 58]
# start****************************************************
# dataIndex
# 59
# hashVals
# [5.0, -10.0, -9.0]
# fp
# 4294967076
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53]}
# node.buckets[fp]
# [53, 59]
# start****************************************************
# dataIndex
# 60
# hashVals
# [4.0, -9.0, -8.0]
# fp
# 4294967102
# index
# 2
# node.val
# 2
# node.buckets
# {4294967142: [5, 15, 18], 4294967152: [14], 4294967042: [50, 52]}
# node.buckets[fp]
# [60]
# start****************************************************
# dataIndex
# 61
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55]}
# node.buckets[fp]
# [55, 61]
# start****************************************************
# dataIndex
# 62
# hashVals
# [5.0, -10.0, -8.0]
# fp
# 4294967086
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59]}
# node.buckets[fp]
# [62]
# start****************************************************
# dataIndex
# 63
# hashVals
# [6.0, -12.0, -9.0]
# fp
# 4294967051
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36], 4294967051: [51, 56]}
# node.buckets[fp]
# [51, 56, 63]
# start****************************************************
# dataIndex
# 64
# hashVals
# [5.0, -10.0, -8.0]
# fp
# 4294967086
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59], 4294967086: [62]}
# node.buckets[fp]
# [62, 64]
# start****************************************************
# dataIndex
# 65
# hashVals
# [5.0, -12.0, -9.0]
# fp
# 4294967058
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58]}
# node.buckets[fp]
# [54, 58, 65]
# start****************************************************
# dataIndex
# 66
# hashVals
# [6.0, -11.0, -9.0]
# fp
# 4294967060
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22]}
# node.buckets[fp]
# [66]
# start****************************************************
# dataIndex
# 67
# hashVals
# [5.0, -10.0, -9.0]
# fp
# 4294967076
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59], 4294967086: [62, 64]}
# node.buckets[fp]
# [53, 59, 67]
# start****************************************************
# dataIndex
# 68
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61]}
# node.buckets[fp]
# [55, 61, 68]
# start****************************************************
# dataIndex
# 69
# hashVals
# [5.0, -10.0, -9.0]
# fp
# 4294967076
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67], 4294967086: [62, 64]}
# node.buckets[fp]
# [53, 59, 67, 69]
# start****************************************************
# dataIndex
# 70
# hashVals
# [6.0, -12.0, -10.0]
# fp
# 4294967041
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36], 4294967051: [51, 56, 63]}
# node.buckets[fp]
# [70]
# start****************************************************
# dataIndex
# 71
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68]}
# node.buckets[fp]
# [55, 61, 68, 71]
# start****************************************************
# dataIndex
# 72
# hashVals
# [5.0, -12.0, -9.0]
# fp
# 4294967058
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58, 65]}
# node.buckets[fp]
# [54, 58, 65, 72]
# start****************************************************
# dataIndex
# 73
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71]}
# node.buckets[fp]
# [55, 61, 68, 71, 73]
# start****************************************************
# dataIndex
# 74
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73]}
# node.buckets[fp]
# [55, 61, 68, 71, 73, 74]
# start****************************************************
# dataIndex
# 75
# hashVals
# [5.0, -12.0, -9.0]
# fp
# 4294967058
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58, 65, 72]}
# node.buckets[fp]
# [54, 58, 65, 72, 75]
# start****************************************************
# dataIndex
# 76
# hashVals
# [5.0, -12.0, -9.0]
# fp
# 4294967058
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58, 65, 72, 75]}
# node.buckets[fp]
# [54, 58, 65, 72, 75, 76]
# start****************************************************
# dataIndex
# 77
# hashVals
# [6.0, -13.0, -10.0]
# fp
# 4294967032
# index
# 2
# node.val
# 2
# node.buckets
# {4294967142: [5, 15, 18], 4294967152: [14], 4294967042: [50, 52], 4294967102: [60]}
# node.buckets[fp]
# [77]
# start****************************************************
# dataIndex
# 78
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74]}
# node.buckets[fp]
# [55, 61, 68, 71, 73, 74, 78]
# start****************************************************
# dataIndex
# 79
# hashVals
# [5.0, -10.0, -8.0]
# fp
# 4294967086
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69], 4294967086: [62, 64]}
# node.buckets[fp]
# [62, 64, 79]
# start****************************************************
# dataIndex
# 80
# hashVals
# [5.0, -10.0, -8.0]
# fp
# 4294967086
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69], 4294967086: [62, 64, 79]}
# node.buckets[fp]
# [62, 64, 79, 80]
# start****************************************************
# dataIndex
# 81
# hashVals
# [5.0, -10.0, -8.0]
# fp
# 4294967086
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69], 4294967086: [62, 64, 79, 80]}
# node.buckets[fp]
# [62, 64, 79, 80, 81]
# start****************************************************
# dataIndex
# 82
# hashVals
# [5.0, -10.0, -8.0]
# fp
# 4294967086
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69], 4294967086: [62, 64, 79, 80, 81]}
# node.buckets[fp]
# [62, 64, 79, 80, 81, 82]
# start****************************************************
# dataIndex
# 83
# hashVals
# [6.0, -12.0, -10.0]
# fp
# 4294967041
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36], 4294967051: [51, 56, 63], 4294967041: [70]}
# node.buckets[fp]
# [70, 83]
# start****************************************************
# dataIndex
# 84
# hashVals
# [6.0, -11.0, -9.0]
# fp
# 4294967060
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66]}
# node.buckets[fp]
# [66, 84]
# start****************************************************
# dataIndex
# 85
# hashVals
# [6.0, -12.0, -9.0]
# fp
# 4294967051
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36], 4294967051: [51, 56, 63], 4294967041: [70, 83]}
# node.buckets[fp]
# [51, 56, 63, 85]
# start****************************************************
# dataIndex
# 86
# hashVals
# [6.0, -12.0, -9.0]
# fp
# 4294967051
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36], 4294967051: [51, 56, 63, 85], 4294967041: [70, 83]}
# node.buckets[fp]
# [51, 56, 63, 85, 86]
# start****************************************************
# dataIndex
# 87
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78]}
# node.buckets[fp]
# [55, 61, 68, 71, 73, 74, 78, 87]
# start****************************************************
# dataIndex
# 88
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87]}
# node.buckets[fp]
# [55, 61, 68, 71, 73, 74, 78, 87, 88]
# start****************************************************
# dataIndex
# 89
# hashVals
# [5.0, -10.0, -9.0]
# fp
# 4294967076
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69], 4294967086: [62, 64, 79, 80, 81, 82]}
# node.buckets[fp]
# [53, 59, 67, 69, 89]
# start****************************************************
# dataIndex
# 90
# hashVals
# [5.0, -10.0, -9.0]
# fp
# 4294967076
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89], 4294967086: [62, 64, 79, 80, 81, 82]}
# node.buckets[fp]
# [53, 59, 67, 69, 89, 90]
# start****************************************************
# dataIndex
# 91
# hashVals
# [6.0, -11.0, -9.0]
# fp
# 4294967060
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66, 84]}
# node.buckets[fp]
# [66, 84, 91]
# start****************************************************
# dataIndex
# 92
# hashVals
# [5.0, -10.0, -9.0]
# fp
# 4294967076
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90], 4294967086: [62, 64, 79, 80, 81, 82]}
# node.buckets[fp]
# [53, 59, 67, 69, 89, 90, 92]
# start****************************************************
# dataIndex
# 93
# hashVals
# [5.0, -9.0, -8.0]
# fp
# 4294967095
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57]}
# node.buckets[fp]
# [57, 93]
# start****************************************************
# dataIndex
# 94
# hashVals
# [5.0, -10.0, -9.0]
# fp
# 4294967076
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92], 4294967086: [62, 64, 79, 80, 81, 82]}
# node.buckets[fp]
# [53, 59, 67, 69, 89, 90, 92, 94]
# start****************************************************
# dataIndex
# 95
# hashVals
# [6.0, -11.0, -9.0]
# fp
# 4294967060
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66, 84, 91]}
# node.buckets[fp]
# [66, 84, 91, 95]
# start****************************************************
# dataIndex
# 96
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88]}
# node.buckets[fp]
# [55, 61, 68, 71, 73, 74, 78, 87, 88, 96]
# start****************************************************
# dataIndex
# 97
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96]}
# node.buckets[fp]
# [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97]
# start****************************************************
# dataIndex
# 98
# hashVals
# [5.0, -9.0, -8.0]
# fp
# 4294967095
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93]}
# node.buckets[fp]
# [57, 93, 98]
# start****************************************************
# dataIndex
# 99
# hashVals
# [5.0, -11.0, -9.0]
# fp
# 4294967067
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97]}
# node.buckets[fp]
# [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99]
# start****************************************************
# dataIndex
# 100
# hashVals
# [7.0, -13.0, -13.0]
# fp
# 4294966995
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98]}
# node.buckets[fp]
# [100]
# start****************************************************
# dataIndex
# 101
# hashVals
# [7.0, -12.0, -12.0]
# fp
# 4294967014
# index
# 4
# node.val
# 4
# node.buckets
# {}
# node.buckets[fp]
# [101]
# start****************************************************
# dataIndex
# 102
# hashVals
# [7.0, -14.0, -13.0]
# fp
# 4294966986
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82]}
# node.buckets[fp]
# [102]
# start****************************************************
# dataIndex
# 103
# hashVals
# [7.0, -12.0, -13.0]
# fp
# 4294967004
# index
# 4
# node.val
# 4
# node.buckets
# {4294967014: [101]}
# node.buckets[fp]
# [103]
# start****************************************************
# dataIndex
# 104
# hashVals
# [7.0, -13.0, -13.0]
# fp
# 4294966995
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100]}
# node.buckets[fp]
# [100, 104]
# start****************************************************
# dataIndex
# 105
# hashVals
# [7.0, -15.0, -13.0]
# fp
# 4294966977
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99]}
# node.buckets[fp]
# [105]
# start****************************************************
# dataIndex
# 106
# hashVals
# [6.0, -10.0, -12.0]
# fp
# 4294967039
# index
# 9
# node.val
# 9
# node.buckets
# {}
# node.buckets[fp]
# [106]
# start****************************************************
# dataIndex
# 107
# hashVals
# [7.0, -14.0, -13.0]
# fp
# 4294966986
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82], 4294966986: [102]}
# node.buckets[fp]
# [102, 107]
# start****************************************************
# dataIndex
# 108
# hashVals
# [7.0, -13.0, -13.0]
# fp
# 4294966995
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104]}
# node.buckets[fp]
# [100, 104, 108]
# start****************************************************
# dataIndex
# 109
# hashVals
# [8.0, -15.0, -13.0]
# fp
# 4294966970
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66, 84, 91, 95]}
# node.buckets[fp]
# [109]
# start****************************************************
# dataIndex
# 110
# hashVals
# [7.0, -13.0, -12.0]
# fp
# 4294967005
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108]}
# node.buckets[fp]
# [110]
# start****************************************************
# dataIndex
# 111
# hashVals
# [7.0, -12.0, -12.0]
# fp
# 4294967014
# index
# 4
# node.val
# 4
# node.buckets
# {4294967014: [101], 4294967004: [103]}
# node.buckets[fp]
# [101, 111]
# start****************************************************
# dataIndex
# 112
# hashVals
# [7.0, -13.0, -12.0]
# fp
# 4294967005
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108], 4294967005: [110]}
# node.buckets[fp]
# [110, 112]
# start****************************************************
# dataIndex
# 113
# hashVals
# [6.0, -11.0, -12.0]
# fp
# 4294967030
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66, 84, 91, 95], 4294966970: [109]}
# node.buckets[fp]
# [113]
# start****************************************************
# dataIndex
# 114
# hashVals
# [7.0, -12.0, -12.0]
# fp
# 4294967014
# index
# 4
# node.val
# 4
# node.buckets
# {4294967014: [101, 111], 4294967004: [103]}
# node.buckets[fp]
# [101, 111, 114]
# start****************************************************
# dataIndex
# 115
# hashVals
# [7.0, -13.0, -12.0]
# fp
# 4294967005
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108], 4294967005: [110, 112]}
# node.buckets[fp]
# [110, 112, 115]
# start****************************************************
# dataIndex
# 116
# hashVals
# [7.0, -13.0, -12.0]
# fp
# 4294967005
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108], 4294967005: [110, 112, 115]}
# node.buckets[fp]
# [110, 112, 115, 116]
# start****************************************************
# dataIndex
# 117
# hashVals
# [8.0, -15.0, -14.0]
# fp
# 4294966960
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66, 84, 91, 95], 4294966970: [109], 4294967030: [113]}
# node.buckets[fp]
# [117]
# start****************************************************
# dataIndex
# 118
# hashVals
# [7.0, -15.0, -14.0]
# fp
# 4294966967
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105]}
# node.buckets[fp]
# [118]
# start****************************************************
# dataIndex
# 119
# hashVals
# [6.0, -11.0, -12.0]
# fp
# 4294967030
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66, 84, 91, 95], 4294966970: [109], 4294967030: [113], 4294966960: [117]}
# node.buckets[fp]
# [113, 119]
# start****************************************************
# dataIndex
# 120
# hashVals
# [7.0, -14.0, -13.0]
# fp
# 4294966986
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82], 4294966986: [102, 107]}
# node.buckets[fp]
# [102, 107, 120]
# start****************************************************
# dataIndex
# 121
# hashVals
# [7.0, -11.0, -12.0]
# fp
# 4294967023
# index
# 3
# node.val
# 3
# node.buckets
# {}
# node.buckets[fp]
# [121]
# start****************************************************
# dataIndex
# 122
# hashVals
# [7.0, -15.0, -13.0]
# fp
# 4294966977
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105], 4294966967: [118]}
# node.buckets[fp]
# [105, 122]
# start****************************************************
# dataIndex
# 123
# hashVals
# [6.0, -12.0, -12.0]
# fp
# 4294967021
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36], 4294967051: [51, 56, 63, 85, 86], 4294967041: [70, 83]}
# node.buckets[fp]
# [123]
# start****************************************************
# dataIndex
# 124
# hashVals
# [7.0, -13.0, -13.0]
# fp
# 4294966995
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108], 4294967005: [110, 112, 115, 116]}
# node.buckets[fp]
# [100, 104, 108, 124]
# start****************************************************
# dataIndex
# 125
# hashVals
# [7.0, -14.0, -13.0]
# fp
# 4294966986
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82], 4294966986: [102, 107, 120]}
# node.buckets[fp]
# [102, 107, 120, 125]
# start****************************************************
# dataIndex
# 126
# hashVals
# [6.0, -12.0, -12.0]
# fp
# 4294967021
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36], 4294967051: [51, 56, 63, 85, 86], 4294967041: [70, 83], 4294967021: [123]}
# node.buckets[fp]
# [123, 126]
# start****************************************************
# dataIndex
# 127
# hashVals
# [7.0, -12.0, -12.0]
# fp
# 4294967014
# index
# 4
# node.val
# 4
# node.buckets
# {4294967014: [101, 111, 114], 4294967004: [103]}
# node.buckets[fp]
# [101, 111, 114, 127]
# start****************************************************
# dataIndex
# 128
# hashVals
# [7.0, -13.0, -13.0]
# fp
# 4294966995
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124], 4294967005: [110, 112, 115, 116]}
# node.buckets[fp]
# [100, 104, 108, 124, 128]
# start****************************************************
# dataIndex
# 129
# hashVals
# [7.0, -13.0, -13.0]
# fp
# 4294966995
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124, 128], 4294967005: [110, 112, 115, 116]}
# node.buckets[fp]
# [100, 104, 108, 124, 128, 129]
# start****************************************************
# dataIndex
# 130
# hashVals
# [7.0, -14.0, -13.0]
# fp
# 4294966986
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82], 4294966986: [102, 107, 120, 125]}
# node.buckets[fp]
# [102, 107, 120, 125, 130]
# start****************************************************
# dataIndex
# 131
# hashVals
# [8.0, -15.0, -13.0]
# fp
# 4294966970
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66, 84, 91, 95], 4294966970: [109], 4294967030: [113, 119], 4294966960: [117]}
# node.buckets[fp]
# [109, 131]
# start****************************************************
# dataIndex
# 132
# hashVals
# [7.0, -13.0, -13.0]
# fp
# 4294966995
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124, 128, 129], 4294967005: [110, 112, 115, 116]}
# node.buckets[fp]
# [100, 104, 108, 124, 128, 129, 132]
# start****************************************************
# dataIndex
# 133
# hashVals
# [7.0, -12.0, -12.0]
# fp
# 4294967014
# index
# 4
# node.val
# 4
# node.buckets
# {4294967014: [101, 111, 114, 127], 4294967004: [103]}
# node.buckets[fp]
# [101, 111, 114, 127, 133]
# start****************************************************
# dataIndex
# 134
# hashVals
# [7.0, -12.0, -13.0]
# fp
# 4294967004
# index
# 4
# node.val
# 4
# node.buckets
# {4294967014: [101, 111, 114, 127, 133], 4294967004: [103]}
# node.buckets[fp]
# [103, 134]
# start****************************************************
# dataIndex
# 135
# hashVals
# [7.0, -15.0, -13.0]
# fp
# 4294966977
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105, 122], 4294966967: [118]}
# node.buckets[fp]
# [105, 122, 135]
# start****************************************************
# dataIndex
# 136
# hashVals
# [7.0, -13.0, -13.0]
# fp
# 4294966995
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124, 128, 129, 132], 4294967005: [110, 112, 115, 116]}
# node.buckets[fp]
# [100, 104, 108, 124, 128, 129, 132, 136]
# start****************************************************
# dataIndex
# 137
# hashVals
# [7.0, -13.0, -12.0]
# fp
# 4294967005
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124, 128, 129, 132, 136], 4294967005: [110, 112, 115, 116]}
# node.buckets[fp]
# [110, 112, 115, 116, 137]
# start****************************************************
# dataIndex
# 138
# hashVals
# [7.0, -12.0, -12.0]
# fp
# 4294967014
# index
# 4
# node.val
# 4
# node.buckets
# {4294967014: [101, 111, 114, 127, 133], 4294967004: [103, 134]}
# node.buckets[fp]
# [101, 111, 114, 127, 133, 138]
# start****************************************************
# dataIndex
# 139
# hashVals
# [7.0, -13.0, -12.0]
# fp
# 4294967005
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124, 128, 129, 132, 136], 4294967005: [110, 112, 115, 116, 137]}
# node.buckets[fp]
# [110, 112, 115, 116, 137, 139]
# start****************************************************
# dataIndex
# 140
# hashVals
# [7.0, -13.0, -13.0]
# fp
# 4294966995
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124, 128, 129, 132, 136], 4294967005: [110, 112, 115, 116, 137, 139]}
# node.buckets[fp]
# [100, 104, 108, 124, 128, 129, 132, 136, 140]
# start****************************************************
# dataIndex
# 141
# hashVals
# [7.0, -13.0, -12.0]
# fp
# 4294967005
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124, 128, 129, 132, 136, 140], 4294967005: [110, 112, 115, 116, 137, 139]}
# node.buckets[fp]
# [110, 112, 115, 116, 137, 139, 141]
# start****************************************************
# dataIndex
# 142
# hashVals
# [7.0, -12.0, -12.0]
# fp
# 4294967014
# index
# 4
# node.val
# 4
# node.buckets
# {4294967014: [101, 111, 114, 127, 133, 138], 4294967004: [103, 134]}
# node.buckets[fp]
# [101, 111, 114, 127, 133, 138, 142]
# start****************************************************
# dataIndex
# 143
# hashVals
# [7.0, -14.0, -13.0]
# fp
# 4294966986
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82], 4294966986: [102, 107, 120, 125, 130]}
# node.buckets[fp]
# [102, 107, 120, 125, 130, 143]
# start****************************************************
# dataIndex
# 144
# hashVals
# [7.0, -14.0, -13.0]
# fp
# 4294966986
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82], 4294966986: [102, 107, 120, 125, 130, 143]}
# node.buckets[fp]
# [102, 107, 120, 125, 130, 143, 144]
# start****************************************************
# dataIndex
# 145
# hashVals
# [7.0, -13.0, -12.0]
# fp
# 4294967005
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124, 128, 129, 132, 136, 140], 4294967005: [110, 112, 115, 116, 137, 139, 141]}
# node.buckets[fp]
# [110, 112, 115, 116, 137, 139, 141, 145]
# start****************************************************
# dataIndex
# 146
# hashVals
# [6.0, -12.0, -12.0]
# fp
# 4294967021
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36], 4294967051: [51, 56, 63, 85, 86], 4294967041: [70, 83], 4294967021: [123, 126]}
# node.buckets[fp]
# [123, 126, 146]
# start****************************************************
# dataIndex
# 147
# hashVals
# [7.0, -13.0, -12.0]
# fp
# 4294967005
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124, 128, 129, 132, 136, 140], 4294967005: [110, 112, 115, 116, 137, 139, 141, 145]}
# node.buckets[fp]
# [110, 112, 115, 116, 137, 139, 141, 145, 147]
# start****************************************************
# dataIndex
# 148
# hashVals
# [7.0, -13.0, -12.0]
# fp
# 4294967005
# index
# 5
# node.val
# 5
# node.buckets
# {4294967095: [57, 93, 98], 4294966995: [100, 104, 108, 124, 128, 129, 132, 136, 140], 4294967005: [110, 112, 115, 116, 137, 139, 141, 145, 147]}
# node.buckets[fp]
# [110, 112, 115, 116, 137, 139, 141, 145, 147, 148]
# start****************************************************
# dataIndex
# 149
# hashVals
# [7.0, -12.0, -12.0]
# fp
# 4294967014
# index
# 4
# node.val
# 4
# node.buckets
# {4294967014: [101, 111, 114, 127, 133, 138, 142], 4294967004: [103, 134]}
# node.buckets[fp]
# [101, 111, 114, 127, 133, 138, 142, 149]
# end-------------------------------------------------
# start****************************************************
# dataIndex
# 0
# hashVals
# [7.0, 12.0, 9.0]
# fp
# 149
# index
# 9
# node.val
# 9
# node.buckets
# {4294967039: [106]}
# node.buckets[fp]
# [0]
# start****************************************************
# dataIndex
# 1
# hashVals
# [6.0, 11.0, 8.0]
# fp
# 137
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105, 122, 135], 4294966967: [118]}
# node.buckets[fp]
# [1]
# start****************************************************
# dataIndex
# 2
# hashVals
# [6.0, 11.0, 8.0]
# fp
# 137
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105, 122, 135], 4294966967: [118], 137: [1]}
# node.buckets[fp]
# [1, 2]
# start****************************************************
# dataIndex
# 3
# hashVals
# [6.0, 11.0, 7.0]
# fp
# 127
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105, 122, 135], 4294966967: [118], 137: [1, 2]}
# node.buckets[fp]
# [3]
# start****************************************************
# dataIndex
# 4
# hashVals
# [7.0, 12.0, 9.0]
# fp
# 149
# index
# 9
# node.val
# 9
# node.buckets
# {4294967039: [106], 149: [0]}
# node.buckets[fp]
# [0, 4]
# start****************************************************
# dataIndex
# 5
# hashVals
# [7.0, 13.0, 9.0]
# fp
# 158
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58, 65, 72, 75, 76]}
# node.buckets[fp]
# [5]
# start****************************************************
# dataIndex
# 6
# hashVals
# [6.0, 11.0, 8.0]
# fp
# 137
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105, 122, 135], 4294966967: [118], 137: [1, 2], 127: [3]}
# node.buckets[fp]
# [1, 2, 6]
# start****************************************************
# dataIndex
# 7
# hashVals
# [6.0, 12.0, 8.0]
# fp
# 146
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82], 4294966986: [102, 107, 120, 125, 130, 143, 144]}
# node.buckets[fp]
# [7]
# start****************************************************
# dataIndex
# 8
# hashVals
# [6.0, 10.0, 7.0]
# fp
# 118
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58, 65, 72, 75, 76], 158: [5]}
# node.buckets[fp]
# [8]
# start****************************************************
# dataIndex
# 9
# hashVals
# [6.0, 11.0, 7.0]
# fp
# 127
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105, 122, 135], 4294966967: [118], 137: [1, 2, 6], 127: [3]}
# node.buckets[fp]
# [3, 9]
# start****************************************************
# dataIndex
# 10
# hashVals
# [7.0, 13.0, 9.0]
# fp
# 158
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58, 65, 72, 75, 76], 158: [5], 118: [8]}
# node.buckets[fp]
# [5, 10]
# start****************************************************
# dataIndex
# 11
# hashVals
# [6.0, 11.0, 8.0]
# fp
# 137
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105, 122, 135], 4294966967: [118], 137: [1, 2, 6], 127: [3, 9]}
# node.buckets[fp]
# [1, 2, 6, 11]
# start****************************************************
# dataIndex
# 12
# hashVals
# [6.0, 11.0, 7.0]
# fp
# 127
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105, 122, 135], 4294966967: [118], 137: [1, 2, 6, 11], 127: [3, 9]}
# node.buckets[fp]
# [3, 9, 12]
# start****************************************************
# dataIndex
# 13
# hashVals
# [6.0, 10.0, 7.0]
# fp
# 118
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58, 65, 72, 75, 76], 158: [5, 10], 118: [8]}
# node.buckets[fp]
# [8, 13]
# start****************************************************
# dataIndex
# 14
# hashVals
# [8.0, 14.0, 10.0]
# fp
# 170
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66, 84, 91, 95], 4294966970: [109, 131], 4294967030: [113, 119], 4294966960: [117]}
# node.buckets[fp]
# [14]
# start****************************************************
# dataIndex
# 15
# hashVals
# [8.0, 13.0, 11.0]
# fp
# 171
# index
# 1
# node.val
# 1
# node.buckets
# {4294967151: [0, 4, 7, 10, 16, 17, 19, 20, 21, 23, 24, 26, 27, 28, 31, 32, 33, 39, 40, 43, 44, 46, 48, 49], 4294967161: [36], 4294967051: [51, 56, 63, 85, 86], 4294967041: [70, 83], 4294967021: [123, 126, 146]}
# node.buckets[fp]
# [15]
# start****************************************************
# dataIndex
# 16
# hashVals
# [7.0, 13.0, 10.0]
# fp
# 168
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58, 65, 72, 75, 76], 158: [5, 10], 118: [8, 13]}
# node.buckets[fp]
# [16]
# start****************************************************
# dataIndex
# 17
# hashVals
# [7.0, 12.0, 9.0]
# fp
# 149
# index
# 9
# node.val
# 9
# node.buckets
# {4294967039: [106], 149: [0, 4]}
# node.buckets[fp]
# [0, 4, 17]
# start****************************************************
# dataIndex
# 18
# hashVals
# [7.0, 13.0, 9.0]
# fp
# 158
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58, 65, 72, 75, 76], 158: [5, 10], 118: [8, 13], 168: [16]}
# node.buckets[fp]
# [5, 10, 18]
# start****************************************************
# dataIndex
# 19
# hashVals
# [7.0, 12.0, 9.0]
# fp
# 149
# index
# 9
# node.val
# 9
# node.buckets
# {4294967039: [106], 149: [0, 4, 17]}
# node.buckets[fp]
# [0, 4, 17, 19]
# start****************************************************
# dataIndex
# 20
# hashVals
# [7.0, 13.0, 8.0]
# fp
# 148
# index
# 8
# node.val
# 8
# node.buckets
# {4294967158: [25], 4294967058: [54, 58, 65, 72, 75, 76], 158: [5, 10, 18], 118: [8, 13], 168: [16]}
# node.buckets[fp]
# [20]
# start****************************************************
# dataIndex
# 21
# hashVals
# [7.0, 12.0, 9.0]
# fp
# 149
# index
# 9
# node.val
# 9
# node.buckets
# {4294967039: [106], 149: [0, 4, 17, 19]}
# node.buckets[fp]
# [0, 4, 17, 19, 21]
# start****************************************************
# dataIndex
# 22
# hashVals
# [7.0, 11.0, 9.0]
# fp
# 140
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66, 84, 91, 95], 4294966970: [109, 131], 4294967030: [113, 119], 4294966960: [117], 170: [14]}
# node.buckets[fp]
# [22]
# start****************************************************
# dataIndex
# 23
# hashVals
# [6.0, 12.0, 8.0]
# fp
# 146
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82], 4294966986: [102, 107, 120, 125, 130, 143, 144], 146: [7]}
# node.buckets[fp]
# [7, 23]
# start****************************************************
# dataIndex
# 24
# hashVals
# [6.0, 11.0, 8.0]
# fp
# 137
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105, 122, 135], 4294966967: [118], 137: [1, 2, 6, 11], 127: [3, 9, 12]}
# node.buckets[fp]
# [1, 2, 6, 11, 24]
# start****************************************************
# dataIndex
# 25
# hashVals
# [6.0, 12.0, 7.0]
# fp
# 136
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82], 4294966986: [102, 107, 120, 125, 130, 143, 144], 146: [7, 23]}
# node.buckets[fp]
# [25]
# start****************************************************
# dataIndex
# 26
# hashVals
# [6.0, 12.0, 8.0]
# fp
# 146
# index
# 6
# node.val
# 6
# node.buckets
# {4294967186: [13], 4294967076: [53, 59, 67, 69, 89, 90, 92, 94], 4294967086: [62, 64, 79, 80, 81, 82], 4294966986: [102, 107, 120, 125, 130, 143, 144], 146: [7, 23], 136: [25]}
# node.buckets[fp]
# [7, 23, 26]
# start****************************************************
# dataIndex
# 27
# hashVals
# [7.0, 12.0, 9.0]
# fp
# 149
# index
# 9
# node.val
# 9
# node.buckets
# {4294967039: [106], 149: [0, 4, 17, 19, 21]}
# node.buckets[fp]
# [0, 4, 17, 19, 21, 27]
# start****************************************************
# dataIndex
# 28
# hashVals
# [7.0, 12.0, 8.0]
# fp
# 139
# index
# 9
# node.val
# 9
# node.buckets
# {4294967039: [106], 149: [0, 4, 17, 19, 21, 27]}
# node.buckets[fp]
# [28]
# start****************************************************
# dataIndex
# 29
# hashVals
# [6.0, 11.0, 8.0]
# fp
# 137
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45], 4294967177: [35], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 99], 4294966977: [105, 122, 135], 4294966967: [118], 137: [1, 2, 6, 11, 24], 127: [3, 9, 12]}
# node.buckets[fp]
# [1, 2, 6, 11, 24, 29]
# ...
# fp
# 4294967173
# index
# 3
# node.val
# 3
# node.buckets
# {4294967023: [121], 153: [68, 72, 87], 4294967143: [59, 64], 4294967133: [82, 84, 96, 99], 4294967183: [54, 61, 63, 70, 76, 78, 91, 97], 4294967193: [66], 4294967223: [113]}
# node.buckets[fp]
# [135]
# start****************************************************
# dataIndex
# 136
# hashVals
# [7.0, -1.0, -5.0]
# fp
# 4294967183
# index
# 3
# node.val
# 3
# node.buckets
# {4294967023: [121], 153: [68, 72, 87], 4294967143: [59, 64], 4294967133: [82, 84, 96, 99], 4294967183: [54, 61, 63, 70, 76, 78, 91, 97], 4294967193: [66], 4294967223: [113], 4294967173: [135]}
# node.buckets[fp]
# [54, 61, 63, 70, 76, 78, 91, 97, 136]
# start****************************************************
# dataIndex
# 137
# hashVals
# [6.0, -1.0, -5.0]
# fp
# 4294967190
# index
# 0
# node.val
# 0
# node.buckets
# {4294967160: [3, 6, 11, 29, 30, 42, 47], 4294967170: [22], 4294967060: [66, 84, 91, 95], 4294966970: [109, 131], 4294967030: [113, 119], 4294966960: [117], 170: [14], 140: [22], 150: [138], 4294967110: [50, 52, 72, 76, 86], 4294967120: [51, 54, 56, 58, 63, 65, 73, 74, 75, 83, 87, 91], 4294967140: [53, 61, 89, 92, 94], 4294967130: [55, 62, 66, 70, 71, 78, 85, 97], 4294967200: [55, 59, 67, 82, 84, 88, 89, 90, 92, 94, 95, 96, 99], 4294967190: [68, 72, 73, 83, 87, 102, 104, 110, 112, 115, 120, 124, 125, 129], 4294967180: [105, 107, 122, 130], 4294967240: [106]}
# node.buckets[fp]
# [68, 72, 73, 83, 87, 102, 104, 110, 112, 115, 120, 124, 125, 129, 137]
# start****************************************************
# dataIndex
# 138
# hashVals
# [5.0, -1.0, -4.0]
# fp
# 4294967207
# index
# 7
# node.val
# 7
# node.buckets
# {4294967167: [1, 2, 8, 9, 12, 34, 37, 38, 41, 45, 51, 86], 4294967177: [35, 18, 20], 4294967067: [55, 61, 68, 71, 73, 74, 78, 87, 88, 96, 97, 